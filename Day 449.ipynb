# %%
import time
print("welcome to KBC")
time.sleep(1)
print("Lets play KBC")
time.sleep(1)
que = ("what is love","when do i can be calm","where is home","how to work")

opt1 = ("a. blind","b. sam","c. hat","d. baby dont hurt me")
opt2 = ("a. by crying","b. by music","c. by destroying","d. by head")
opt3 = ("a. water","b. air","c. here","d. earth")
opt4 = ("a. home","b. bad","c. sad","d. mad")



cash = ("2000","20000","200000","2000000")


print("your first question if you choose to answer is on the screen")
time.sleep(1)
print(que[0])
print(opt1)
a = str(input("please choose your options"))
if a == "d":
    print("correct option !!! you win Rs",cash[0])
    time.sleep(1)
    
    print("next question on your screen is ")
    time.sleep(1)
    print(que[1]) 
    print(opt2)
    
    b = str(input("please choose your options"))
    if b == "b":
        print("correct option !!! you win Rs",cash[1])
    
        
        print("next question on your screen is ")
        time.sleep(1)
        print(que[2]) 
        print(opt3)
        
        c = str(input("please choose your options"))
        
        if c == "c":
            print("correct option !!! you win Rs",cash[2])
            
            print("next question on your screen is ")
            time.sleep(1)
            print(que[3]) 
            print(opt4)
        
            d = str(input("please choose your options"))
        
            if d == "a":
                print("correct option !!! you win Rs",cash[3])
            else:
                print("wrong answer !!! your take away amount is Rs",cash[2])
            
            
        else:
            print("wrong answer !!! your take away amount is Rs",cash[1])

    else:
        print("wrong answer !!! your take away amount is Rs",cash[0])

else:
    print("wrong answer you take home amount is zero ")
# Out:
# welcome to KBC
# Lets play KBC
# your first question if you choose to answer is on the screen
# what is love
# ('a. blind', 'b. sam', 'c. hat', 'd. baby dont hurt me')
# correct option !!! you win Rs 2000
# next question on your screen is
# when do i can be calm
# ('a. by crying', 'b. by music', 'c. by destroying', 'd. by head')
# correct option !!! you win Rs 20000
# next question on your screen is
# where is home
# ('a. water', 'b. air', 'c. here', 'd. earth')
# correct option !!! you win Rs 200000
# next question on your screen is
# how to work
# ('a. home', 'b. bad', 'c. sad', 'd. mad')
# wrong answer !!! your take away amount is Rs 200000
